# %% [markdown]
# # For-Schleifen und Ranges
# ## Voraussetzungen
# Diese Einheit setzt voraus, dass Sie folgende Inhalte kennen: Variablen, Ein- und Ausgabe, primitive und komplexe Datentypen.
# ## `For`-Schleifen
# Schleifen werden in der Programmierung benötigt, um eine Gruppe von Anweisungen mehrfach zu durchlaufen. Die Programmiersprache Python kennt zwei Arten von Schleifen, die `while`-Schleife und die `for`-Schleife. Die `for`-Schleife ist ein Sprachelement, dass sich sehr gut zur Bearbeitung von Zeichenketten (Buchstabe für Buchstabe), Listen (Element für Element) oder Zahlenintervallen eignet. Zeichenketten, Listen und Zahlenintervalle werden in Python auch allgemeiner als [*Sequenz*](https://docs.python.org/3/library/stdtypes.html#sequence-types-list-tuple-range) bezeichnet.
#
# Bei der Bearbeitung einer Sequenz mit einer `for`-Schleife wird in jedem Durchlauf ein Element der Sequenz einer Variablen zugewiesen. Danach werden alle Anweisungen innerhalb der Schleife ausgeführt. Die allgemeine Syntax der `for`-Schleife in Python ist:
#
# ```python
# for Variable in Sequenz:
#     Anweisung_1
#     Anweisung_2
#     ...
#     Anweisung_n
# ```
# Folgende Graphik verdeutlicht die Ausführung einer `for`-Schleife
# ![for_loop.png](./img/for_loop.png)
# ### Dokumentation
# Die Dokumentation zur `for`-Schleife finden Sie [hier](https://docs.python.org/3/tutorial/controlflow.html#for-statements).
# ### Beispiele
# Um z.B. eine Zeichenkette Buchstabe für Buchstabe zu durchlaufen und jeden Buchstaben auszugeben kann folgender Python-Code verwendet werden.

# %%
for buchstabe in "Hallo Python-Progammierung":
    print(buchstabe)

# %% [markdown]
# Natürlich ist es auch möglich die `for`-Schleife mit anderen Kontrollstrukturen zu kombinieren. Die Anzahl der Vorkommen des Buchstaben 'o' in der Zeichenkette "Hallo Python-Programmierung" kann mit folgendem Python-Code berechnet werden.

# %%
zaehler = 0
for buchstabe in "Hallo Python-Progammierung":
    if buchstabe == 'o':
        zaehler += 1
        
print("Die Zeichenkette enthällt den Buchstaben 'o'", zaehler, "mal.")

# %% [markdown]
# Wie bereits oben erwähnt kann die `for`-Schleife dafür verwendet werden die Elemente einer Sequenz zu verarbeiten. Folgendes Beispiel zeigt, wie mit einer
# `for`-Schleife die Elemente einer Liste verarbeitet werden können.

# %%
aufnahmen = ["Leave Home", "Rocket to Russia", "Road to Ruin", "Mondo Bizarro"]

for aufnahme in aufnahmen:
    print("Ich höre das Album:", aufnahme)

# %% [markdown]
# ## Aufgabe 1
# Nun sind Sie an der Reihe. Schreiben Sie ein Programm, welches zuerst die Eingabe eines Satzes und dann die Eingabe eines Buchstabens vom Anwender erwartet. Das Programm soll
# den eingegebenen Satz ausgeben und dabei jedes Auftreten des eingegebenen Buchstabens entfernen.
#
# Die Ausgabe soll wie folgt aussehen (Benutzereingaben zur verdeutlichung __fett__):
# > Welcher Satz soll ausgegeben werden? __So soll das aussehen__  <br>
# > Welcher Buchstabe nicht? __s__ <br>
# So oll da auehen
#
# Einen automatisierten [Test](#Test-zur-Aufgabe-1) für Ihre Lösung finden Sie weiter unten im Dokument.

# %%
def aufgabe1():
    ###BEGIN SOLUTION
    satz = input("Welcher Satz soll ausgegeben werden? ")
    buchstabe_zum_beseitigen = input("Welcher Buchstabe nicht? ")
    
    ergebnis = ""
    for buchstabe in satz:
        if buchstabe != buchstabe_zum_beseitigen:
            ergebnis += buchstabe
    
    print(ergebnis)
    ###END SOLUTION
        
aufgabe1()

# %% [markdown]
# ## Ranges
# In Python existiert ein eigener Datentyp, um ein Intervall von Zahlen zu repräsentieren. Dieser Datentyp wird als
# [*Range*](https://docs.python.org/3/library/stdtypes.html#ranges) bezeichnet. Ranges können in Python durch Aufruf der
# Funktion `range` erzeugt werden. Der Aufruf der 'range'-Funktion in Python ist in folgenden Code-Ausschnitt dargestellt:
# ```python
#   range([start,] end [,step])
#   ```
# Der Aufruf der `range`-Funktion muss das Ende des Intervalls enthalten (im Parameter `end`). Außerdem können optional
# der Beginn des Intervalls (Parameter `start`) und eine Schrittweite (Paramteter `step`) übergeben werden. Eine
# Range, welche die Zahlen von 0 bis 4 enthält kann demnach mit folgendem Funktionsaufruf erstellt werden:
# ```python
#   range(5) # -> 0 1 2 3 4
# ```
#   Alternativ kann für eine Range auch ein von 0 abweichender Anfangswert definiert werden. Hierzu wird die `range`-Funktion mit zwei Parametern
#   aufgerufen. Folgender Funktionsaufruf erstellt einen Range im Intervall von 10 bis 15.
# ```python
#   range(10,6) # -> 10 11 12 13 14 15
# ```
# Mit Hilfe der Schrittweite kann der Abstand der Zahlen im Intervall definiert werden. Die Schrittweite kann dabei
# sowohl negativ als auch positiv sein.
# ```python
#   range(2,12,3) # -> 2 5 8 11
#   range(20,5,-5) # -> 20 15 10
# ```
# ### Dokumentation
# Die Dokumentation zur `range`-Funktion finden Sie [hier](https://docs.python.org/3/tutorial/controlflow.html#the-range-function).
#
# ### Ranges und die `for`-Schleife
# In Kombination mit der `for`-Schleife können Ranges verwendet werden um die Anzahl der Schleifendurchläufe zu steuern.
# Dies wird in den folgenden Beispielen näher erläutert. Um z.B. die Zahlen von 0 bis 9 auszugeben kann folgeder Python-Code verwendet werden:

# %%
for nummer in range(10):
    print(nummer)

# %% [markdown]
# Die Zahlen von 10 bis 19 lassen sich wie folgt ausgeben:

# %%
for nummer in range(10, 20):
    print(nummer)

# %% [markdown]
# Zu guter letzt kann auch noch die Schrittweite des Intervalls, dass durch die Range dargestellt wird, angepasst werden.
# Folgender Python-Code gibt z.B. alle Zahlen von 10 bis 0 in Zweierschritten aus.

# %%
for nummer in range(10, 0, -2):
    print(nummer)

# %% [markdown]
# ## Aufgabe 2
# Nun sind Sie wieder an der Reihe. Schreiben Sie ein Python-Programm, das als Eingabe eine natürliche Zahl erwartet und die Summe aller natürlichen Zahlen bis zu der eingegebenen Zahl berechnet.
#
# Die Ausgabe soll wie folgt aussehen (Benutzereingaben zur verdeutlichung __fett__):
# > Bis zu welcher Zahl soll die Summe berechnet werden? __100__  <br>
# 5050
#
# Einen automatisierten [Test](#Test-zur-Aufgabe-2) für Ihre Lösung finden Sie weiter unten im Dokument.

# %%
def aufgabe2():
    ###BEGIN SOLUTION
    
    nummer = int(input("Bis zu welcher Zahl soll die Summe berechnet werden? "))
    summe = 0
    
    for aktuelle_nummer in range(nummer + 1):
        summe += aktuelle_nummer
    
    print(summe)
    ###END SOLUTION
    
    
aufgabe2()

# %% [markdown]
# ## Aufgabe 3
# ### FizzBuzz
# Schreiben Sie ein Programm, dass die Zahlen von 1 bis 100 ausgibt.
# Dabei sollen alle Zahlen, die durch drei teilbar sind, durch "Fizz" und alle Zahlen die durch 5 teilbar sind werden durch "Buzz" ersetzt.
# Zahlen, die sowohl durch 3 als auch durch 5 teilbar sind, werden durch "FizzBuzz" ersetzt.
# Hinweis: Die Teilbarkeit können Sie mit dem Modulo-Operator `%` überprüfen.
# Die Ausgabe der Funktion soll wie folgt aussehen:
# >1  <br>
# 2  <br>
# Fizz  <br>
# 4  <br>
# Buzz  <br>
# Fizz  <br>
# 7
#
# Einen automatisierten [Test](#Test-zur-Aufgabe-3) für Ihre Lösung finden Sie weiter unten im Dokument.

# %%
def aufgabe3():
    ###BEGIN SOLUTION
    
    for nummer in range(1, 101):
        if nummer % 3 == 0 and nummer % 5 == 0:
            print("FizzBuzz")
        elif nummer % 3 == 0:
            print("Fizz")
        elif nummer % 5 == 0:
            print("Buzz")
        else:
            print(nummer)
            
    
    ###END SOLUTION
    
    
aufgabe3()

# %% [markdown]
# ## Aufgabe 4
# ### Primzahlen
# Schreiben Sie ein Programm, welches alle Zahlen von 2 – 1000 durchläuft und ausgibt ob die Zahl eine Primzahl ist.
# Eine Zahl ist dann prim, wenn Sie nur durch sich selbst und durch 1 teilbar ist.
# Um zu prüfen, ob eine Zahl n prim ist, muss für alle Zahlen von 2 bis n-1 geprüft werden, ob sie n teilen können.
# Trifft das für keine Zahl zu, dann ist n prim.
# Für die Lösung der Aufgabe werden somit zwei in einander geschachtelte Schleifen benötigt.
#
# Die Ausgabe der Funktion soll also wie folgt aussehen:
# >2 prim  <br>
# 3 prim  <br>
# 4  <br>
# 5 prim <br>
# 6  <br>
# 7 prim <br>
# 8  <br>
# 9  <br>
# ...
#
# Einen automatisierten [Test](#Test-zur-Aufgabe-4) für Ihre Lösung finden Sie weiter unten im Dokument.

# %%
def aufgabe4():
    ###BEGIN SOLUTION
    
    for nummer in range(2, 1001):

        ist_prim = True

        for test_nummer in range(2, nummer):
            if nummer % test_nummer == 0:
                ist_prim = False
        
        if ist_prim:
            print(nummer, "prim")
        else:
            print(nummer)

    ###END SOLUTION
    
    
aufgabe4()

# %% [markdown]
# ***
#    ## Automatisierte Tests zu den Übungen
#    Ab hier finden Sie einige automatisierte Tests, um Ihre Lösungen zu überprüfen.
#    Um Ihre Lösung zu prüfen führen Sie bitte zuerst die Zelle mit Ihrer Lösung und danach die Zelle mit dem zugehörigen Test aus.

# %% [markdown]
# ### Test zur [Aufgabe 1](#Aufgabe-1)

# %%
from unittest import mock
import unittest
import io

with mock.patch('builtins.input', side_effect=["Drei Chinesen mit dem Kontrabass", "e"]):
    with mock.patch('sys.stdout', new=io.StringIO()) as fake_stdout:
        aufgabe1()

    assert fake_stdout.getvalue() == 'Dri Chinsn mit dm Kontrabass\n'

# %% [markdown]
# ### Test zur [Aufgabe 2](#Aufgabe-2)

# %%
from unittest import mock
import unittest
import io

with mock.patch('builtins.input', return_value='7'):
    with mock.patch('sys.stdout', new=io.StringIO()) as fake_stdout:
        aufgabe2()
        
    assert fake_stdout.getvalue() == '28\n'

# %% [markdown]
# ### Test zur [Aufgabe 3](#Aufgabe-3)

# %%
from unittest import mock
import unittest
import io

with mock.patch('sys.stdout', new=io.StringIO()) as fake_stdout:
    aufgabe3()

assert fake_stdout.getvalue() == '1\n2\nFizz\n4\nBuzz\nFizz\n7\n8\nFizz\nBuzz\n11\nFizz\n13\n14\nFizzBuzz\n16\n17\nFizz\n19\nBuzz\nFizz\n22\n23\nFizz\nBuzz\n26\nFizz\n28\n29\nFizzBuzz\n31\n32\nFizz\n34\nBuzz\nFizz\n37\n38\nFizz\nBuzz\n41\nFizz\n43\n44\nFizzBuzz\n46\n47\nFizz\n49\nBuzz\nFizz\n52\n53\nFizz\nBuzz\n56\nFizz\n58\n59\nFizzBuzz\n61\n62\nFizz\n64\nBuzz\nFizz\n67\n68\nFizz\nBuzz\n71\nFizz\n73\n74\nFizzBuzz\n76\n77\nFizz\n79\nBuzz\nFizz\n82\n83\nFizz\nBuzz\n86\nFizz\n88\n89\nFizzBuzz\n91\n92\nFizz\n94\nBuzz\nFizz\n97\n98\nFizz\nBuzz\n'

# %% [markdown]
# ### Test zur [Aufgabe 4](#Aufgabe-4)

# %%
from unittest import mock
import unittest
import io

with mock.patch('sys.stdout', new=io.StringIO()) as fake_stdout:
    aufgabe4()

assert fake_stdout.getvalue() == '2 prim\n3 prim\n4\n5 prim\n6\n7 prim\n8\n9\n10\n11 prim\n12\n13 prim\n14\n15\n16\n17 prim\n18\n19 prim\n20\n21\n22\n23 prim\n24\n25\n26\n27\n28\n29 prim\n30\n31 prim\n32\n33\n34\n35\n36\n37 prim\n38\n39\n40\n41 prim\n42\n43 prim\n44\n45\n46\n47 prim\n48\n49\n50\n51\n52\n53 prim\n54\n55\n56\n57\n58\n59 prim\n60\n61 prim\n62\n63\n64\n65\n66\n67 prim\n68\n69\n70\n71 prim\n72\n73 prim\n74\n75\n76\n77\n78\n79 prim\n80\n81\n82\n83 prim\n84\n85\n86\n87\n88\n89 prim\n90\n91\n92\n93\n94\n95\n96\n97 prim\n98\n99\n100\n101 prim\n102\n103 prim\n104\n105\n106\n107 prim\n108\n109 prim\n110\n111\n112\n113 prim\n114\n115\n116\n117\n118\n119\n120\n121\n122\n123\n124\n125\n126\n127 prim\n128\n129\n130\n131 prim\n132\n133\n134\n135\n136\n137