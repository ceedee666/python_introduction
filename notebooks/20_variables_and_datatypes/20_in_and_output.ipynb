# %% [markdown]
#  # Eingaben und Ausgaben
#  ## Voraussetzungen
#  Diese Einheit setzt voraus, dass Sie folgende Inhalte kennen: Variablen.
#  ## Ausgaben
#  Wird eine Zelle eines Jupyter-Notebooks ausgeführt, wird immer nur das Ergebnis der letzten
#  Anweisung ausgegeben. Wenn die letzte Anweisung jedoch kein dartellbares Erbebnis hat (wie z.B. die Zuweisung
#  eines Wertes zu einer Variablen) erfoglt keine Ausgabe. Über die Python-Funktion `print` is es möglich
#  Ausgaben an jeder beliebiegen Stelle eines Python-Programms zu erzeugen.

# %%
print("Hello")
print(42)

name = "Joey"
print(name)

# %% [markdown]
#  Was ausgegeben werden soll wird der Funktion `print`als Parameter übergeben.
#
#  Außerdem ist es auch möglich meherer Parameter an die Funktion `print` zu übergeben. Diese müssen dann durch
#  ein Komma (`,`) voneinander getrennt werden.

# %%
name = "Joey"
lastname = "Ramone"

print(name, lastname)

# %% [markdown]
#  ## Eingaben
#  Erinnern Sie sich an die Übung zur Berechung der Oberfläche und des Volumens eines Quaders?
#  Einen Berechnung der Werrte für einen neuen Quader ist bisher recht mühsam. Sie müssen jedesmal:
#  - In die Zelle des Notebooks gehen und das Python-Programm ändern.
#  - Die Zelle erneut ausführen.

# %% [markdown]
#  Einfacher wäre es, wenn das Programm die zu verarbeitenden Daten als *Eingabe* erfragen würde. Das Python-Programm
#  sollte unabhängig von den Kantenlängen eines konkreten Quaders sein.
#  Das ist der klassische Aufbau eines Programms nach EVA-Prinzip: Eingabe → Verarbeitung → Ausgabe
#  ### Die Funktion input
#
#  Mit Hilfe der Funktion `input()` können Sie Eingaben von Benutzer einlesen. Ein typischer Aufruf der Funktion
#  `input()` ist:
#
#  ```python
#  i = input("Bitte geben Sie eine Zahl ein:")
#  print(i)
#  ```

# %%
i = input("Bitte geben Sie eine Zahl ein: ")
print(i)

# %% [markdown]
#  Die Funktion `input()` gibt zuerst den übergebenen Parameter ("Bitte …") aus.
#  Danach wartet die Funktion auf eine Eingabe vom Benutzer. Der Benutzer gibt einen Wert ein und beendet die Eingabe
#  mit der Returntaste (Eingabetaste). Der eingegebene Wert wird der Variablen *i* zugewiesen.

# %% [markdown]
#   ## Übung:
#   Schreiben Sie ein Programm, dass über `input()` Werte für Vorname, Nachname und Email-Adresse abfragt bekommt. Geben Sie die Eingegebenen Werte danach aus.
