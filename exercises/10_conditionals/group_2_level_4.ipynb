# %% [markdown]
# # Aufgabe 4
# In einem Versicherungsunternehmen soll, im Rahmen der Gebäudeversicherungen, ein Programm zur automatischen Risikobewertung implementiert werden. Zur Bewertung des Risikos sollen folgende Regeln verwendet werden:
#
# - Ein Gebäude in Risikoklasse "D" eingestuft werden, wenn es sich um ein Mehrfamilienhaus handelt.
# - Handelt es sich bei dem Gebäude nicht um ein Mehrfamilienhaus, wird das Alter des Gebäudes überprüft .
#     - Ist das Alter des Gebäudes kleiner oder gleich 10 Jahren, soll es in die Risikoklasse "A" eingestuft werden.
#     - Ist das Alter des Gebäudes größer als 10 Jahre und kleiner oder gleich 20 Jahre, soll es in die Risikoklasse "C" eingestuft werden.
#     - Ist das Alter des Gebäudes größer als 20 Jahre, soll es in die Risikoklasse "C" eingestuft werden.
#
# Implementieren Sie nun die Funktion `risikobewertung`. Diese Funktion erhält folgende Parameter:
#
# - Der Parameter `alter` gibt das Alter des Gebäudes in Jahren an und ist vom Typ `Integer`.
# - Der Parameter `ist_mehrfamilienhaus` gibt an ob das Gebäude ein Mehrfamilienhaus ist und ist vom Typ `Boolean`.
#
# Als Ergebnis der Funktion `risikobewertung` sollen die Variable `risikoklasse` berechnet werden.
#
# ## Wichtige Hinweise
# Bisher haben Sie im Rahmen dieser Einführung in Python Funktionen noch nicht kennen gelernt. Aus diesem Grund hier ein paar Hinweise zum Umgang mit Funktionen im Rahmen dieser Übungsaufgaben:
#
# 1. Erstellen Sie Ihre Lösung innerhalb des mit `### START` und `### ENDE` markierten Bereichs. Ändern Sie den Programmcode außerhalb des markierten Bereichs nicht.
# 1. Funktionen besitzen Parameter. Diese Parameter haben Namen. Behandel Sie die Parameter einfach wie Variablen in Ihrer Lösung.
# 1. Bitte löschen Sie ggf die Zeile `raise NotImplementedError()`

# %%
def risikobewertung(alter, ist_mehrfamilienhaus):
    
    ###START
    
    ###ENDE
    
    return risikoklasse

print("Wenn Ihre Funktion mit den Parametern \"age = 5\" und \"ist_mehrfamilienhaus = True\" aufgerufen wird, ist die berechnete Risikoklasse:", risikobewertung(5, True))

# %% [markdown]
#  ***
#  # Automatische Tests
#  Ab hier finden Sie einige automatisierte Tests um Ihre Lösungen zu überprüfen. Um Ihre Lösung zu prüfen führen Sie bitte zuerst die Zelle mit Ihrer Lösung und danach die Zelle mit dem zugehörigen Test aus.

# %% [markdown]
#  ## Test 1 - Korrekte Bedingungen
#  Die Risikoklasse (`risikoklasse`) soll "D" sein, wenn es sich bei dem Gebäude um ein Mehrfamilienhaus handelt **oder** das Gebäude älter als 20 Jahre ist.
#  Ist dies nicht der Fall soll die Risikoklasse "A" oder "B" sein, je nachdem ob das Gebäude jünger als 10 Jahre ist oder zwischen 11 und 20 Jahren.

# %%
import sys
sys.path.append("../..")
from nose.tools import assert_equal, assert_not_equal
from utils import * 

alter = 5
ist_mehrfamilienhaus = True
try:
    risikoklasse = risikobewertung(alter, ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "D")
    print("[OK] Die Risikoklasse für eine Mehrfamilienhaus ist D.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"D\" sein wenn das Gebäude ein Mehrfamilienhaus ist.")
    print("       ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))


alter = 25
ist_mehrfamilienhaus = False
try:
    risikoklasse = risikobewertung(alter, ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "D")
    print("[OK] Die Risikoklasse für eine Haus das älter als 20 Jahre ist ist D.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"D\" sein wenn das Gebäude älter als 20 Jahre ist.")
    print("       ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))
    
    
alter = 15
ist_mehrfamilienhaus = False
try:
    risikoklasse = risikobewertung(alter, ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "B")
    print("[OK] Die Risikoklasse für ein Gebäude, das kein Mehrfamilienhaus und zwichen 11 und 20 Jahre alt ist, ist B.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"B\" sein wenn das Gebäude kein Mehrfamilienhaus und zwichen 11 und 20 Jahre alt ist.")
    print("       ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))
    

alter = 5
ist_mehrfamilienhaus = False
try:
    risikoklasse = risikobewertung(alter, ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "A")
    print("[OK] Die Risikoklasse für ein Gebäude, das kein Mehrfamilienhaus und jünger als 10 Jahre ist, ist A.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"A\" sein wenn das Gebäude kein Mehrfamilienhaus und jünger als 10 Jahre ist.")
    print("       ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))

alter = 25
ist_mehrfamilienhaus = True
try:
    risikoklasse = risikobewertung(alter, ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "D")
    print("[OK] Die Risikoklasse für eine Haus das ein Mehrfamilienhaus und älter als 20 Jahre ist, ist D.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"D\" sein wenn das Gebäude ein Meherfamilienhaus und älter als 20 Jahre ist.")
    print("       ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))

# %% [markdown]
#  ## Test 2 - Beachtung der Randfälle
#  Die Risikoklasse (`risikoklasse`) soll auch dann "A" sein wenn das Gebäude kein Mehrfamilienhaus ist und *genau* 10 Jahre alt ist. Ebenso gehört ein *genau* 20 Jahre altes Gebäude noch zur Risikoklasse "B".

# %%
alter = 10
ist_mehrfamilienhaus = False
try:
    risikoklasse = risikobewertung(alter, ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "A")
    print("[OK] Die Risikoklasse für ein Gebäude, das kein Mehrfamilienhaus und genau 10 Jahre alt ist, ist A.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"A\" sein wenn das Gebäude kein Mehrfamilienhaus und genau 10 Jahre alt ist.")
    print("       ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))


alter = 20
ist_mehrfamilienhaus = False
try:
    risikoklasse = risikobewertung(alter, ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "B")
    print("[OK] Die Risikoklasse für ein Gebäude, das kein Mehrfamilienhaus und genau 20 Jahre alt ist, ist A.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"B\" sein wenn das Gebäude kein Mehrfamilienhaus und genau 20 Jahre alt ist.")
    print("       ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))
