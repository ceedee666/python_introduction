# %% [markdown]
#    # Aufgabe 1
#
#    In einem Versicherungsunternehmen soll, im Rahmen der Gebäudeversicherungen, ein Programm zur automatischen Risikobewertung implementiert werden. Im ersten Schritt wollen Sie zunächst nur überprüfen ob es sich bei einem Gebäude um ein Mehrfamilienhaus handelt. Ist dies der Fall so ist die Risikoklasse in jedem Fall "D".
#
#    Implementieren Sie nun die Funktion `insurance_classification`. Diese Funktion erhält einen Parameter `is_apartement_building`, welcher in Form eines Boolean-Wertes angibt ob das Gebäude ein Mehrfamilienhaus ist (True oder False).
#    Als Ergebnis soll jedoch die Risikoklasse in Form eines Buchstabens zurückgegeben werden. Ist das Gebäude ein Mehrfamilienhaus, so geben Sie "D" zurück. Ansonsten geben Sie "A" zurück.
#
#
#  ## Wichtige Hinweise
#  Bisher haben Sie im Rahmen dieser Einführung in Python Funktionen noch nicht kennen gelernt. Aus diesem Grund hier ein paar Hinweise zum Umgang mit Funktionen im Rahmen dieser Übungsaufgaben:
#
#  1. Erstellen Sie Ihre Lösung innerhalb des mit `### START` und `### ENDE` markierten Bereichs. Ändern Sie den Programmcode außerhalb des markierten Bereichs nicht.
#  1. Funktionen besitzen Parameter. Diese Parameter haben Namen. Behandeln Sie die Parameter einfach wie Variablen in Ihrer Lösung.
#  1. Bitte löschen Sie ggf die Zeile `raise NotImplementedError()`
#
#  ### Hilfe
#    Sie können Ihre Lösung mit den automatisierten [Tests](#Automatische-Tests) weiter unten im Dokument überprüfen.<br>
#    Eine Einführung in die `Kontrollstrukturen`in Python finden Sie [hier](../../30_conditionals/10_conditionals.ipynb).

# %%
def risikobewertung(ist_mehrfamilienhaus):
    
    ### START

    risikoklasse = "A"
    if # Bedingung. Prüfen ob das Gebäude ein Mehrfamilienhaus ist
        risikoklasse = "D"

    ### ENDE
    return risikoklasse

print("Wenn die Funktion mit einem Parameter \"ist_mehrfamilienhaus = True\" aufgerufen wird ist die berechente Risikoklasse: ", risikobewertung(True))

# %% [markdown]
# ***
# # Automatische Tests
# Ab hier finden Sie einige automatisierte Tests um Ihre Lösungen zu überprüfen. Um Ihre Lösung zu prüfen führen Sie
# bitte zuerst die Zelle mit Ihrer Lösung und danach die Zelle mit dem zugehörigen Test aus.

# %% [markdown]
# ## Test 1 - Korrekte Bedingung
# Die Risikoklasse (`insurance_class`) soll "D" sein wenn das Gebäude ein Mehrfamilienhaus ist. Ansonsten soll sie "A" sein.

# %%
import sys
sys.path.append("../..")
from nose.tools import assert_equal, assert_not_equal
from utils import * 

ist_mehrfamilienhaus = True
try:
    risikoklasse = risikobewertung(ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "D")
    print("[OK] Test die Risikoklasse = D wenn das Gebäude ein Mehrfamilienhaus ist.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"D\" sein wenn das Gebäude ein Mehrfamilienhaus ist.")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e)) 
    
    
ist_mehrfamilienhaus = False
try:
    risikoklasse = risikobewertung(ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "A")
    print("[OK] Test die Risikoklasse = A wenn das Gebäude kein Mehrfamilienhaus ist.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"A\" sein wenn das Gebäude kein Mehrfamilienhaus ist.")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

# %% [markdown]
# ## Test 2 - Truthyness in Python
# In Python werde unter bestimmten Umständen auch die Werte andere Datentypen als `Boolean` als `True` oder `False` interpretiert.
# Dieser Test prüft ob auch wirklich nur die Risikoklasse D ausgegeben wird wenn ìs_apartment_building = True` gilt.

# %%
ist_mehrfamilienhaus = "Tolles Haus mit Aussicht"
try:
    risikoklasse = risikobewertung(ist_mehrfamilienhaus)

    assert_equal(risikoklasse, "A")
    print("OK] Die Risikoklasse ist nur dann \"D\"  wenn der Paramter ist_mehrfamilienhaus den Wert True enthält.")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll nur dann \"D\" sein wenn der Paramter ist_mehrfamilienhaus einen anderen Wert True enthält.")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))
