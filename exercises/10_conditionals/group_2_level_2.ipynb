# %% [markdown]
#  # Aufgabe 2
#  In einem Versicherungsunternehmen soll, im Rahmen der Gebäudeversicherungen, ein Programm zur automatische
#  Risikobewertung implementiert werden. Zur Bewertung des Risikos soll das Alter des Gebäudes verwendet werden.
#  Ist das Alter eines Gebäudes kleiner oder gleich 10 Jahren dann ist die zugehörige Risikoklasse "A". Ist das Gebäude älter, dann ist die zugehörige Risikoklasse "D".
#
#  Implementieren Sie die Funktion `risikobewertung`. Diese Funktion erhält einen Parameter `alter`, welcher in Form eines Integer-Wertes angibt wie alt ein Gebäude ist (in Jahren).
#  Als Ergebnis der Funktion `risikobewertung` sollen die Variablen `risikoklasse` und `einstufung` berechnet werden.
#  Ist das Gebäude älter als 10 Jahre, so soll die Variable `risikoklasse` auf den Wert "D" und die Variable `einstufung` auf den Wert "alt" gesetzt werden.
#  Ist das Alter des Gebäudes kleiner oder gleich 10 Jahre, so soll die Variable `risikoklasse` auf den Wert "A" und die Variable `einstufung` auf den Wert "neu" gesetzt werden.
#
#  ## Wichtige Hinweise
#  Bisher haben Sie im Rahmen dieser Einführung in Python Funktionen noch nicht kennen gelernt. Aus diesem Grund hier ein paar Hinweise zum Umgang mit Funktionen im Rahmen dieser Übungsaufgaben:
#
#  1. Erstellen Sie Ihre Lösung innerhalb des mit `### START` und `### ENDE` markierten Bereichs. Ändern Sie den Programmcode außerhalb des markierten Bereichs nicht.
#  1. Funktionen besitzen Parameter. Diese Parameter haben Namen. Behandeln Sie die Parameter einfach wie Variablen in Ihrer Lösung.
#  1. Bitte löschen Sie ggf die Zeile `raise NotImplementedError()`
#
#  ### Hilfe
#  Sie können Ihre Lösung mit den automatisierten [Tests](#Automatische-Tests) weiter unten im Dokument überprüfen.<br>
#  Eine Einführung in die `Kontrollstrukturen`in Python finden Sie [hier](../../30_conditionals/10_conditionals.ipynb).

# %%
def risikobewertung(alter):
    
    ###START
    
    ###ENDE
    
    return risikoklasse, einstufung

print("Wenn die Funktion risikobewertung mit dem Parameter \"alter = 5\" aufgerufen wird ist die berechent Risikoklasse", risikobewertung(5)[0], "und die berechnete Einstufung", risikobewertung(5)[1])

# %% [markdown]
#  ***
#  # Automatische Tests
#  Ab hier finden Sie einige automatisierte Tests um Ihre Lösungen zu überprüfen. Um Ihre Lösung zu prüfen führen Sie bitte zuerst die Zelle mit Ihrer Lösung und danach die Zelle mit dem zugehörigen Test aus.

# %% [markdown]
#  ## Test 1 - Korrekte Bedingung
#  Die Risikoklasse (`risikoklasse`) soll "D" und die Einstufung "alt" sein wenn das Gebäude älter als 10 Jahre ist. Ansonsten sollen sie "A" und "neu" sein.

# %%
import sys
sys.path.append("../..")
from nose.tools import assert_equal, assert_not_equal
from utils import * 

age = 20
try:
    risikoklasse, einstufung = risikobewertung(age)

    assert_equal(risikoklasse, "D")
    assert_equal(einstufung.lower(), "alt")
    print("[OK] Test Risikoklasse = \"D\" und Einstufung = \"alt\" wenn das Gebäude älter al 10 Jahre ist. ")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"D\" und die Einstufung \"alt\" sein wenn das Gebäude älter als 10 Jahre ist. ")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))
    
age = 5
try:
    risikoklasse, einstufung = risikobewertung(age)

    assert_equal(risikoklasse, "A")
    assert_equal(einstufung.lower(), "neu")
    print("[OK] Test Risikoklasse = \"A\" und Einstufung = \"neu\" wenn das Gebäude jünger als 10 Jahre ist. ")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"A\" und die Einstufung \"neu\" sein wenn das Gebäude älter als 10 Jahre ist. ")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))

# %% [markdown]
#  ## Test 2 - Beachtung der Randfälle
#  Die Risikoklasse (`risikoklasse`) soll auch "A" und die Einstufung "neu" sein wenn das Gebäude genau 10 Jahre alt ist.

# %%
from nose.tools import assert_equal
from utils import *

age = 11
try:
    risikoklasse, einstufung = risikobewertung(age)

    assert_equal(risikoklasse, "D")
    assert_equal(einstufung.lower(), "alt")
    print("[OK] Test Risikoklasse = \"D\" und Einstufung = \"alt\" wenn das Gebäude älter als 10 Jahre ist. ")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"D\" und die Einstufung \"alt\" sein wenn das Gebäude älter als 10 Jahre ist. ")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))
    
age = 10
try:
    risikoklasse, einstufung = risikobewertung(age)

    assert_equal(risikoklasse, "A")
    assert_equal(einstufung.lower(), "neu")
    print("[OK] Test Risikoklasse = \"A\" und Einstufung = \"neu\" wenn das Gebäude genau 10 Jahre alt ist. ")
except AssertionError as e:
    print("[FEHLER] Die Risikoklasse soll \"A\" und die Einstufung \"neu\" sein wenn das Gebäude genau 10 Jahre alt ist. ")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions(e))
