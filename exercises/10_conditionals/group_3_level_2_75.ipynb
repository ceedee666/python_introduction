# %% [markdown]
# # Aufgabe 2
# In einer Bank sollen Kreditkartenanträge automatisch bearbeitet werden. Sie sollen nun das Regelwerk zur Entscheidung über
# Anträge einem Python Programm umsetzen.
# Im zweiten Schritt soll überprüft werden ob das monatliche Einkommen eines Antragstellers über 1500€ liegt. Nur dann soll eine Kreditkarte ausgestellt werden. Andernfalls ist der Antragsteller nicht berechtigt eine Kreditkarte zu erhalten.
#
# Implementieren Sie die Funktion `antrag_pruefen`. Diese Funktion erhält einen Parameter `monatliches_einkommen`,
# welcher in Form eines `Integer`-Wertes monatliche Einkommen eines Antragstellers enthält.
# Als Ergebnis soll die Funktion die Variablen `ist_berechtigt` und `nachricht` berechnen.
# - Ist das monatliche Einkommen des Antragstellers größer als 1500€ soll die Variable `ist_berechtigt`
# auf den Wert `True` und die Variable `nachricht` auf den Wert `"angenommen"` gesetzt werden.
# - Ansonsten soll die Variable `ist_berechtigt` auf den Wert `False` und die Variable `nachricht` auf den Wert `"abgelehnt"` gesetzt werden.
#
# ## Wichtige Hinweise
# Bisher haben Sie im Rahmen dieser Einführung in Python Funktionen noch nicht kennen gelernt. Aus diesem Grund hier ein paar Hinweise zum Umgang mit Funktionen im Rahmen dieser Übungsaufgaben:
#
# 1. Erstellen Sie Ihre Lösung innerhalb des mit `### START` und `### ENDE` markierten Bereichs. Ändern Sie den Programmcode außerhalb des markierten Bereichs nicht.
# 1. Funktionen besitzen Parameter. Diese Parameter haben Namen. Behandeln Sie die Parameter einfach wie Variablen in Ihrer Lösung.
# 1. Bitte löschen Sie ggf die Zeile `raise NotImplementedError()`
#
# ### Hilfe
# Sie können Ihre Lösung mit den automatisierten [Tests](#Automatische-Tests) weiter unten im Dokument überprüfen.<br>
# Eine Einführung in die `Kontrollstrukturen`in Python finden Sie [hier](../../30_conditionals/10_conditionals.ipynb).

# %%
def antrag_pruefen(monatliches_einkommen):
    ### START

    if  #Bedingung monatliches Einkommen ist kleiner oder gleich 1500
        ist_berechtigt = False
        meldung = "abgelehnt"
    else:
        ist_berechtigt = True
        meldung = "angenommen"

    ### ENDE
    return ist_berechtigt, meldung

print("Wenn Ihre Funktion mit dem Parameter `monatliche_einkommen = 500` aufgerufen ist enthält ìst_berechtigt`den wert", antrag_pruefen(500)[0])

# %% [markdown]
#   ***
#   # Automatische Tests
#   Ab hier finden Sie einige automatisierte Tests um Ihre Lösungen zu überprüfen. Um Ihre Lösung zu prüfen führen Sie bitte zuerst die Zelle mit Ihrer Lösung und danach die Zelle mit dem zugehörigen Test aus.

# %% [markdown]
# ## Test 1 - Rückgabe als Boolean-Wert
# Der Variable `ist_berechtigt` soll einen Wert vom Datentypen `Boolean` enthalten.
# Die Variable `nachricht` soll einen Wert vom Datentypen `String` enthalten.

# %%
import sys
sys.path.append("../..")
from nose.tools import assert_equal, assert_not_equal
from utils import * 

monatliches_einkommen = 3000
try:
    ist_berechtigt, nachricht = antrag_pruefen(monatliches_einkommen)

    assert_equal(isinstance(ist_berechtigt, bool), True)
    assert_equal(isinstance(nachricht, str), True)
    print("[OK] Test Variable `ist_berechtigt` ist vom Datentyp `Boolean`, Variable `nachricht` ist vom Datentypen `String`.")
except AssertionError as e:
    print("[FEHLER]:", "Die Variable `ist_berechtigt` soll vom Datentyp `Boolean`, die Variable `nachricht` vom Datentypen `String` sein. Nutzen Sie keine Anführungszeichen für die Zuweisung von Boolean-Werten.")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

# %% [markdown]
# ## Test 2 - Korrekte Bedingung
# Der Wert der Variablen `ist_berechtigt` soll `True` sein wenn der Antragsteller ein monatliches Einkommen von über 1500€ hat. Ansonsten soll der Wert `False` sein.
# Der Wert der Variablen `nachricht` soll `"angenommen""` sein wenn der Antragsteller ein monatliches Einkommen von über 1500€ hat. Ansonsten soll der Wert `"abgelehnt"` sein.

# %%
import sys
sys.path.append("../..")
from nose.tools import assert_equal, assert_not_equal
from utils import * 

monatliches_einkommen = 3000
try:
    ist_berechtigt, nachricht = antrag_pruefen(monatliches_einkommen)
    assert_equal(ist_berechtigt, True)
    assert_equal(nachricht, "angenommen")
    print("[OK] Test Variable `ist_berechtigt` hat den Wert `True` und Variable `nachricht` den Wert `angenommen` wenn das monatliche Einkommen größer als 1500€ ist.")
except AssertionError as e:
    print("[FEHLER]:", "Die Variable `ist_berechtigt` soll den Wert `True` und die Variable `nachricht` den Wert `angenommen` enthalten wenn das monatliche Einkommen größer als 1500€ ist.")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e)) 
    
monatliches_einkommen = 200
try:
    ist_berechtigt, nachricht = antrag_pruefen(monatliches_einkommen)
    assert_equal(ist_berechtigt, False)
    assert_equal(nachricht, "abgelehnt")
    print("[OK] Test Variable `ist_berechtigt` hat den Wert `False` und Variable `nachricht` den Wert `abgelehnt` wenn das monatliche Einkommen kleiner als 1500€ ist.")
except AssertionError as e:
    print("[FEHLER]:", "Die Variable `ist_berechtigt` soll den Wert `False` und die Variable `nachricht` den Wert `abgelehnt` enthalten wenn das monatliche Einkommen kleiner als 1500€ ist.")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

# %% [markdown]
# ## Test 3 - Beachtung von Randfällen
# Der Wert der Variablen `ist_berechtigt`soll auch dann `False` sein wenn der Antragsteller ein monatliches Einkommen von genau 1500€ hat.

# %%
from utils import *

monatliches_einkommen = 1501
try:
    ist_berechtigt, nachricht = antrag_pruefen(monatliches_einkommen)
    assert_equal(ist_berechtigt, True)
    assert_equal(nachricht, "angenommen")
    print("[OK] Test Variable `ist_berechtigt` hat den Wert `True` und Variable `nachricht` den Wert `angenommen` wenn das monatliche Einkommen größer als 1500€ ist.")
except AssertionError as e:
    print("[FEHLER]:", "Die Variable `ist_berechtigt` soll den Wert `True` und die Variable `nachricht` den Wert `angenommen` enthalten wenn das monatliche Einkommen größer als 1500€ ist.")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e)) 
    
monatliches_einkommen = 1500
try:
    ist_berechtigt, nachricht = antrag_pruefen(monatliches_einkommen)
    assert_equal(ist_berechtigt, False)
    assert_equal(nachricht, "abgelehnt")
    print("[OK] Test Variable `ist_berechtigt` hat den Wert `False` und Variable `nachricht` den Wert `abgelehnt` wenn das monatliche Einkommen genau 1500€ ist.")
except AssertionError as e:
    print("[FEHLER]:", "Die Variable `ist_berechtigt` soll den Wert `False` und die Variable `nachricht` den Wert `abgelehnt` enthalten wenn das monatliche Einkommen genau 1500€ ist.")
    print("        ", e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))
