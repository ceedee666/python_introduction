# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # Aufgabe 4
#
# Es soll ein Programm zur automatischen Analyse von Materialeingängen und Materialabgängen implementiert werden. So soll aus einer großen Liste von Eingängen und Abgängen erkannt werden wie der neue Materialbestand ist. Außerdem soll der größte Ein- oder Abgang bestimmt werden.
#
# Implementieren Sie nun die einzelnen Funktionen `kalkuliere_bestand` und `kalkuliere_hoechstes`.
# Diese Funktionen erhalten als Parameter jeweils eine Liste `eingehend_ausgehend`, welche in Form von Integer-Werten die Eingänge und Abgänge in das Materiallager angibt (in etwa `[+500, -200, +70, -65]`).
# Als Ergebnis sollen (je nach Funktion):
# Der `Materialbestand` in Form eines Integer-Wertes zurückgegeben werden ("bestand").
# Der `höchste Transfer` in Form eines Integer-Wertes zurückgegeben werden ("hoechster_transfer").
#
# Des Weiteren soll eine Hauptfunktion (`analyse_bestand`) implementiert werden. Diese soll die oben genannten Funktionen nur aufrufen und das Ergebnis ausgeben. Dazu soll auch die Hauptfunktion als Parameter eine Liste `eingehend_ausgehend` akzeptieren. Die Ausgabe soll wie folgt aussehen:
# `Der Materialbestand beträgt: 305
# Der höchste Transfer beträgt: 500`
#
#
# Achten Sie bei dieser Aufgabe darauf dass sowohl alle Funktionen einzeln funktionieren, als auch die gesamte Ausgabe über die Hauptfunktion (analyse_stock).
# </div>
# <div class="alert alert-block alert-info">
#
# ### Hilfe
# Sie können Ihre Lösung mit den automatisierten [Tests](#Automatische-Tests) weiter unten im Dokument überprüfen.<br>
# Eine Einführung in die `For-Schleifen` in Python finden Sie [hier](../../50_loops/for_loop.ipynb).
# </div>

# %%
###START
# Hauptfunktion
###ENDE
def kalkuliere_bestand(eingehend_ausgehend):
    bestand = 0
    for transfer in eingehend_ausgehend:
        bestand += transfer
    return bestand
    
def kalkuliere_hoechstes(eingehend_ausgehend):
    hoechster_transfer = 0
    for transfer in eingehend_ausgehend:
        if transfer ** 2 > hoechster_transfer ** 2:
            hoechster_transfer = transfer
    return hoechster_transfer

# %% [markdown]
#   ***
#   # Automatische Tests
#   Ab hier finden Sie einige automatisierte Tests um Ihre Lösungen zu überprüfen. Um Ihre Lösung zu prüfen führen Sie bitte zuerst die Zelle mit Ihrer Lösung und danach die Zelle mit dem zugehörigen Test aus.

# %%
import sys
sys.path.append("../..")
from nose.tools import assert_equal, assert_not_equal
from utils import * 

from unittest import mock
import unittest
import io

try:
    incoming_outgoing = [+519, -250, -19, -12, +234]
    Erg = kalkuliere_bestand(incoming_outgoing)
    expected_out = 472
    assert_equal(Erg, expected_out)
    print("[OK] Der Materialbestand wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"als Materialbestand berechnet, obwohl", expected_out, "der richtige Bestand ist.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    incoming_outgoing = [+99999999, -1234567, -9876543]
    Erg = kalkuliere_bestand(incoming_outgoing)
    expected_out = 88888889
    assert_equal(Erg, expected_out)
    print("[OK] Der Materialbestand wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"als Materialbestand berechnet, obwohl", expected_out, "der richtige Bestand ist.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    incoming_outgoing = [-12, +20]
    Erg = kalkuliere_bestand(incoming_outgoing)
    expected_out = 8
    assert_equal(Erg, expected_out)
    print("[OK] Der Materialbestand wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"als Materialbestand berechnet, obwohl", expected_out, "der richtige Bestand ist.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    incoming_outgoing = [+300, -250, -23, +210, +234]
    Erg = kalkuliere_hoechstes(incoming_outgoing)
    expected_out = 300
    assert_equal(Erg, expected_out)
    print("[OK] Die höchste Materialbewegung wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"als höchste Materialbewegung berechnet, obwohl", expected_out, "die richtige höchste Materialbewegung ist.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    incoming_outgoing = [+200, -200, +200, -200]
    Erg = kalkuliere_hoechstes(incoming_outgoing)
    expected_out = 200
    assert_equal(Erg, expected_out)
    print("[OK] Die höchste Materialbewegung wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"als höchste Materialbewegung berechnet, obwohl", expected_out, "die richtige höchste Materialbewegung ist.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    incoming_outgoing = [+15]
    Erg = kalkuliere_hoechstes(incoming_outgoing)
    expected_out = 15
    assert_equal(Erg, expected_out)
    print("[OK] Die höchste Materialbewegung wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"als höchste Materialbewegung berechnet, obwohl", expected_out, "die richtige höchste Materialbewegung ist.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    incoming_outgoing = [+300, -500, -23, +210, +234]
    Erg = kalkuliere_hoechstes(incoming_outgoing)
    expected_out = -500
    assert_equal(Erg, expected_out)
    print("[OK] Die höchste Materialbewegung wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"als höchste Materialbewegung berechnet, obwohl", expected_out, "die richtige höchste Materialbewegung ist.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    with mock.patch('sys.stdout', new=io.StringIO()) as fake_stdout:
        analyse_bestand([+300, -250, -23, +210, +234])
    expected_out = 'Der Materialbestand beträgt: 471\nDer höchste Transfer beträgt: 300\n'
    assert_equal(fake_stdout.getvalue(), expected_out)
    print("[OK] Die Ausgabe und die Berechnungen sind richtig!")
except AssertionError as e:
    print("[FEHLER] Es wurde",fake_stdout.getvalue() ,"ausgegeben, obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))
