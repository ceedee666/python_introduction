# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # Aufgabe 4
#
# Im Rahmen der Steuerrechnung soll ein Programm zur automatischen Analyse der Umsatzsteuer, welche von Ihrem Unternehmen eingenommen wird, implementiert werden. Dazu sollen die Netto-Verkaufspreise analysiert werden. So soll aus einer Liste mit vielen Einnahmen herausgefiltert werden, welches die höchste eingenommene Umsatzsteuer ist. Außerdem soll die Summe aller eingenommenen Umsatzsteuern berechnet werden.
#
# Implementieren Sie nun die einzelnen Funktionen `analyse_steuern` und `kalkuliere_hoechstes`.
# Diese Funktionen erhalten als Parameter jeweils eine Liste `verkaeufe`, welche in Form von Float-Werten die Netto-Verkaufspreise aller verkauften Artikel angibt (in etwa `[500.00, 299.99, 1.79, 149.49]`).
# Als Ergebnis sollen (je nach Funktion):
# Der gesamte Betrag, welcher durch die Umsatzsteuer eingenommen wurde, in Form eines Float-Wertes zurückgegeben werden ("steuern").
# Der höchste Betrag, welcher durch die Umsatzsteuer an einem Artikel eingenommen wurde, in Form eines Float-Wertes ("hoechste_steuern").
#
# Des Weiteren soll eine Hauptfunktion (`analyse_steuern`) implementiert werden. Diese soll die oben genannten Funktionen nur aufrufen und das Ergebnis ausgeben. Dazu soll auch die Hauptfunktion als Parameter eine Liste `verkaeufe` akzeptieren. Die Ausgabe soll wie folgt aussehen:
# `Die insgesamt eingenommene Umsatzsteuer beträgt: 180.7413
# Die höchste eingenommene Umsatzsteuer beträgt: 95.0`
#
#
# Achten Sie bei dieser Aufgabe darauf dass sowohl alle Funktionen einzeln funktionieren, als auch die gesamte Ausgabe über die Hauptfunktion (analyse_steuern).
#
# Tipp: $ Umsatzsteuer = Nettobetrag * 0.19 $
# </div>
# <div class="alert alert-block alert-info">
#
# ### Hilfe
# Sie können Ihre Lösung mit den automatisierten [Tests](#Automatische-Tests) weiter unten im Dokument überprüfen.<br>
# Eine Einführung in die `For-Schleifen` in Python finden Sie [hier](../../50_loops/for_loop.ipynb).
# </div>

# %%
###START
# Hauptfunktion

# calculate_highest Funktion
###ENDE
def analyse_steuern(verkaeufe):    
    print("Die insgesamt eingenommene Umsatzsteuer beträgt:", kalkuliere_steuern(verkaeufe))
    print("Die höchste eingenommene Umsatzsteuer beträgt:", kalkuliere_hoechstes(verkaeufe))
    return

def kalkuliere_steuern(verkaeufe):
    steuern = 0
    for verkauf in verkaeufe:
        steuern += verkauf * 0.19
    return steuern

# %% [markdown]
#   ***
#   # Automatische Tests
#   Ab hier finden Sie einige automatisierte Tests um Ihre Lösungen zu überprüfen. Um Ihre Lösung zu prüfen führen Sie bitte zuerst die Zelle mit Ihrer Lösung und danach die Zelle mit dem zugehörigen Test aus.

# %%
import sys
sys.path.append("../..")
from nose.tools import assert_equal, assert_not_equal
from utils import * 

from unittest import mock
import unittest
import io

try:
    sales = [519.55, 250.00, 19.37, 12.34, 234.56]
    Erg = kalkuliere_steuern(sales)
    expected_out = 196.80579999999998
    assert_equal(Erg, expected_out)
    print("[OK] Die Umsatzsteuer wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    sales = [99999999.99, 1234567.89, 9876543.22]
    Erg = kalkuliere_steuern(sales)
    expected_out = 21111111.108999997
    assert_equal(Erg, expected_out)
    print("[OK] Die Umsatzsteuer wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    sales = [12.34, 20.00]
    Erg = kalkuliere_steuern(sales)
    expected_out = 6.1446
    assert_equal(Erg, expected_out)
    print("[OK] Die Umsatzsteuer wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    sales = [300.00, 250.00, 23.00, 210.00, 234.00]
    Erg = kalkuliere_hoechstes(sales)
    expected_out = 57
    assert_equal(Erg, expected_out)
    print("[OK] Die höchste Umsatzsteuer wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    sales = [200.00, 200.00, 200.00, 200.00]
    Erg = kalkuliere_hoechstes(sales)
    expected_out = 38
    assert_equal(Erg, expected_out)
    print("[OK] Die höchste Umsatzsteuer wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    sales = [15.00]
    Erg = kalkuliere_hoechstes(sales)
    expected_out = 2.85
    assert_equal(Erg, expected_out)
    print("[OK] Die höchste Umsatzsteuer wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    sales = [300.00, 500.00, 23.00, 210.00, 234.00]
    Erg = kalkuliere_hoechstes(sales)
    expected_out = 95
    assert_equal(Erg, expected_out)
    print("[OK] Die höchste Umsatzsteuer wurde korrekt berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    with mock.patch('sys.stdout', new=io.StringIO()) as fake_stdout:
        analyse_steuern([299.99, 250.00, 23.00, 210.00, 234.00])
    expected_out = 'Die insgesamt eingenommene Umsatzsteuer beträgt: 193.2281\nDie höchste eingenommene Umsatzsteuer beträgt: 56.9981\n'
    assert_equal(fake_stdout.getvalue(), expected_out)
    print("[OK] Die Ausgabe und die Berechnungen sind richtig!")
except AssertionError as e:
    print("[FEHLER] Es wurde",fake_stdout.getvalue() ,"ausgegeben, obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))
