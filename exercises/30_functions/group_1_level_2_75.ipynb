# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # Aufgabe 2
#
# Es soll ein Programm zur automatischen Analyse von Kontobewegungen implementiert werden. So soll aus einer großen Liste von Zugängen und Abgängen erkannt werden wie der neue Kontostand ist. Außerdem soll die durchschnittliche Höhe der Kontobewegungen berechnet werden, sowie der größte Zu- oder Abgang bestimmt werden.
#
# Implementieren Sie nun die Funktion `analyse_transfers`. Diese Funktion erhält als Parameter eine Liste `transfers`, welche in Form von Float-Werten die Zugänge und Abgänge auf das Konto angibt (in etwa `[+500.00, -200.00, +0.70, -0.65]`).
# Als Ergebnis soll der `Kontostand` als Float-Wert zurückgegeben werden ("kontostand").
# Die `durchschnittliche Höhe` einer Kontobewegung ("durchschnitt").
# Der `höchste Transfer` ("hoechster_transfer"). Hierbei sollen sowohl negative als auch positive Transfers berücksichtigt werden.
#
# </div>
# <div class="alert alert-block alert-info">
#
# ### Hilfe
# Sie können Ihre Lösung mit den automatisierten [Tests](#Automatische-Tests) weiter unten im Dokument überprüfen.<br>
# Eine Einführung in die `For-Schleifen` in Python finden Sie [hier](../../50_loops/for_loop.ipynb).
# </div>

# %%
###START

    kontostand = 0
    hoechster_transfer = 0
    for transfer in transfers:
        # Rückgabewert "kontostand" mit jedem durchlauf ändern
        if transfer ** 2 > hoechster_transfer ** 2:
            hoechster_transfer = transfer
    
    # Rückgabewert "durchschnitt" ändern
    
 ###ENDE

# %% [markdown]
#   ***
#   # Automatische Tests
#   Ab hier finden Sie einige automatisierte Tests um Ihre Lösungen zu überprüfen. Um Ihre Lösung zu prüfen führen Sie bitte zuerst die Zelle mit Ihrer Lösung und danach die Zelle mit dem zugehörigen Test aus.

# %%
import sys
sys.path.append("../..")
from nose.tools import assert_equal, assert_not_equal
from utils import * 

try:
    transfers = [+519.55, -250.00, -19.37, -12.34, +234.56]
    Erg = analyse_transfers(transfers)
    expected_out = 472.40
    assert_equal(Erg[0], expected_out)
    print("[OK] Es wurde der richtige Kontostand berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [+99999999.99, -1234567.89, -9876543.22]
    Erg = analyse_transfers(transfers)
    expected_out = 88888888.88
    assert_equal(Erg[0], expected_out)
    print("[OK] Es wurde der richtige Kontostand berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [-12.34, +20.00]
    Erg = analyse_transfers(transfers)
    expected_out = 7.66
    assert_equal(Erg[0], expected_out)
    print("[OK] Es wurde der richtige Kontostand berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [+300.00, -250.00, -23.00, +210.00, +234.00]
    Erg = analyse_transfers(transfers)
    expected_out = 94.2
    assert_equal(Erg[1], expected_out)
    print("[OK] Es wurde der richtige durchschnittliche Kontostand berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde der falsche Durschnitt von",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [+200.00, -200.00, +200.00, -200.00]
    Erg = analyse_transfers(transfers)
    expected_out = 0
    assert_equal(Erg[1], expected_out)
    print("[OK] Es wurde der richtige durchschnittliche Kontostand berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde der falsche Durschnitt von",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [+15.00]
    Erg = analyse_transfers(transfers)
    expected_out = 15
    assert_equal(Erg[1], expected_out)
    print("[OK] Es wurde der richtige durchschnittliche Kontostand berechnet!")
except AssertionError as e:
    print("[FEHLER] Es wurde der falsche Durschnitt von",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [+300.00, -250.00, -23.00, +210.00, +234.00]
    Erg = analyse_transfers(transfers)
    expected_out = 300
    assert_equal(Erg[2], expected_out)
    print("[OK] Es wurde die richtige höchste Bewegung erkannt!")
except AssertionError as e:
    print("[FEHLER] Es wurde die falsche Höchste Bewegung von",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [+200.00, -200.00, +200.00, -200.00]
    Erg = analyse_transfers(transfers)
    expected_out = 200
    assert_equal(Erg[2], expected_out)
    print("[OK] Es wurde die richtige höchste Bewegung erkannt!")
except AssertionError as e:
    print("[FEHLER] Es wurde die falsche Höchste Bewegung von",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [+15.00]
    Erg = analyse_transfers(transfers)
    expected_out = 15
    assert_equal(Erg[2], expected_out)
    print("[OK] Es wurde die richtige höchste Bewegung erkannt!")
except AssertionError as e:
    print("[FEHLER] Es wurde die falsche Höchste Bewegung von",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))

try:
    transfers = [+300.00, -500.00, -23.00, +210.00, +234.00]
    Erg = analyse_transfers(transfers)
    expected_out = -500
    assert_equal(Erg[2], expected_out)
    print("[OK] Es wurde die richtige höchste Bewegung erkannt!")
except AssertionError as e:
    print("[FEHLER] Es wurde die falsche Höchste Bewegung von",Erg ,"berechnet , obwohl ", expected_out, "richtig wäre.")
    print("       ",e)
except Exception as e:
    print("[FEHLER]", friendly_exceptions.msg(e))
